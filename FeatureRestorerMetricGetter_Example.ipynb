# %%
import pandas as pd
import sys

# %%
# !pip install jiwer
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting jiwer
#   Downloading jiwer-2.3.0-py3-none-any.whl (15 kB)
# Collecting python-Levenshtein==0.12.2
#   Downloading python-Levenshtein-0.12.2.tar.gz (50 kB)
#      |████████████████████████████████| 50 kB 1.5 MB/s
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from python-Levenshtein==0.12.2->jiwer) (57.4.0)
# Building wheels for collected packages: python-Levenshtein
#   Building wheel for python-Levenshtein (setup.py) ... done
#   Created wheel for python-Levenshtein: filename=python_Levenshtein-0.12.2-cp37-cp37m-linux_x86_64.whl size=149871 sha256=f494c5d4c745cf122a4a2aed0b8780fc6edf76a24593ed14d6f8ddf7c02236c1
#   Stored in directory: /root/.cache/pip/wheels/05/5f/ca/7c4367734892581bb5ff896f15027a932c551080b2abd3e00d
# Successfully built python-Levenshtein
# Installing collected packages: python-Levenshtein, jiwer
# Successfully installed jiwer-2.3.0 python-Levenshtein-0.12.2

# %%
# Delete feature-restorer-metric-getter folder to ensures that any changes to the repo are reflected
# !rm -rf 'feature-restorer-metric-getter'
# Clone feature-restorer-metric-getter repo
# !git clone https://github.com/ljdyer/feature-restorer-metric-getter.git
# Add feature-restorer-metric-getter to PYTHONPATH
sys.path.append('feature-restorer-metric-getter/src')
from feature_restorer_metric_getter import FeatureRestorerMetricGetter
# Out:
# Cloning into 'feature-restorer-metric-getter'...
# remote: Enumerating objects: 27, done.
# remote: Counting objects: 100% (27/27), done.
# remote: Compressing objects: 100% (21/21), done.
# remote: Total 27 (delta 6), reused 25 (delta 4), pack-reused 0
# Unpacking objects: 100% (27/27), done.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
TEST_PATH = 'drive/MyDrive/PAPER/data/ted_talks/ted_test.csv'
RESULTS_PATH = 'drive/MyDrive/PAPER/models/05_bilstm_e2e/english/TedTalks/results.csv'

# %%
reference = pd.read_csv(TEST_PATH)['all_cleaned'].to_list()
hypothesis = pd.read_csv(RESULTS_PATH)['results'].to_list()

# %%
frmg = FeatureRestorerMetricGetter(reference, hypothesis, True, '., ', False, False)
# Out:
# Initialisation complete.

# %%
frmg.show_prfs()
# Out:
# Getting confusion matrices for all documents...
#   0%|          | 0/800 [00:00<?, ?it/s]
#                 Precision    Recall   F-score
# Capitalisation   0.686844  0.617513  0.650336
# Periods ('.')    0.577247  0.534874  0.555253
# Commas (',')     0.500423  0.378485  0.430995
# Spaces (' ')     0.983378  0.981290  0.982333
# All features     0.915735  0.888753  0.902042

# %%
frmg.show_confusion_matrices()
# Out:
# Getting confusion matrices for all documents...
#   0%|          | 0/800 [00:00<?, ?it/s]
# Capitalisation
# ==============
#                    Hypothesis
#                      positive negative
# Reference positive     100126    62018
#           negative      45651  6116804
# Periods ('.')
# =============
#                    Hypothesis
#                      positive negative
# Reference positive      49716    43233
#           negative      36410  6195240
# Commas (',')
# ============
#                    Hypothesis
#                      positive negative
# Reference positive      41988    68949
#           negative      41917  6171745
# Spaces (' ')
# ============
#                    Hypothesis
#                      positive negative
# Reference positive    1415471    26989
#           negative      23925  4858214
# All features
# ============
#                    Hypothesis
#                      positive  negative
# Reference positive    1607301    201189
#           negative     147903  23342003

# %%
frmg.show_wer_info()
# Out:
# Calculating word error rates for all documents...
#   0%|          | 0/800 [00:00<?, ?it/s]
#                                    Value
# Length of reference (words)    1,443,808
# Minimum edit distance (S+D+I)    295,626
# Word error rate (%)               20.48%
